# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from lxml import etree
import random
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import string

# %%
user_agent_list = [
    # Chrome
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 5.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
    'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36'
    # Firefox
    'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)',
    'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; WOW64; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 6.2; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.0; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)',
    'Mozilla/5.0 (Windows NT 6.1; Win64; x64; Trident/7.0; rv:11.0) like Gecko',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)',
    'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)',
    'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)',
    'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:59.0) Gecko/20100101 Firefox/59.0'
]
def get_random_agent():
    return random.choice(user_agent_list)

# %%
soup1 = '''

<!DOCTYPE html>
<html>
<head>
	<title>BBC Learning English - Lingohack </title>
	<meta name="keywords" content="">
	<meta name="description" content="Get up-to-date with the latest news and understand it too with Lingohack. Listen to and watch authentic BBC news bulletins and learn key words and phrases that help you make sense of the news.">
	<meta http-equiv="content-type" content="text/html; charset=utf-8">
	<meta name="viewport" content="width=device-width, initial-scale=1.0"/>
	<!-- Orbit: 3.0.0-2289.7a752866 -->
<!-- Environment: live -->
<meta name="viewport" content="width=device-width, initial-scale=1.0">

<style>
:root {
    --bbc-font: ReithSans, Arial, Helvetica, freesans, sans-serif;
    --bbc-font-legacy: Arial, Helvetica, freesans, sans-serif;
}
</style>

<script nomodule type="text/javascript" src="https://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/js/polyfills.js"></script>

<link rel="stylesheet" href="https://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/css/orbit-v5-ltr.min.css">
<script src="https://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/js/require.min.js"></script>

<script type="text/javascript">
    window.orbitData = {};

    var additionalPageProperties = {};
        additionalPageProperties['content_language'] = 'en' || null;
        additionalPageProperties['custom_var_1'] = '2022-01-05T09:46:33.565534Z' || null;
        additionalPageProperties['custom_var_2'] = '2022-01-05T11:25:29.439303Z' || null;

    window.orbitData.userProfileUrl = "https://www.bbc.co.uk/userprofile";

    window.page = {
        name: 'learningenglish.features.lingohack_2022.page' || null,
        destination: 'WS_LEARNING_ENGLISH' || null,
        producer: 'WS_LEARNING_ENGLISH' || null,
        section: '' || null,
        site: '' || null,
        contentId: '' || null,
        contentType: 'index-section' || null,
        edition: '' || null,
        additionalProperties: additionalPageProperties
    };
    window.page.language = 'en';
    window.page.language = 'en';

    window.page.modal = false;

</script>

<script type="text/javascript">!function(){var t={930:function(t,e,r){function n(t,e){var r=Object.keys(t);if(Object.getOwnPropertySymbols){var n=Object.getOwnPropertySymbols(t);e&&(n=n.filter((function(e){return Object.getOwnPropertyDescriptor(t,e).enumerable}))),r.push.apply(r,n)}return r}function o(t){for(var e=1;e<arguments.length;e++){var r=null!=arguments[e]?arguments[e]:{};e%2?n(Object(r),!0).forEach((function(e){i(t,e,r[e])})):Object.getOwnPropertyDescriptors?Object.defineProperties(t,Object.getOwnPropertyDescriptors(r)):n(Object(r)).forEach((function(e){Object.defineProperty(t,e,Object.getOwnPropertyDescriptor(r,e))}))}return t}function i(t,e,r){return e in t?Object.defineProperty(t,e,{value:r,enumerable:!0,configurable:!0,writable:!0}):t[e]=r,t}var c=r(382),u=r(19);window.bbcpage=c.init(o({},window.page)),window.page=void 0,window.bbcuser=u.init(window,o({},window.user)),window.user=void 0},382:function(t){function e(t,e){var r=Object.keys(t);if(Object.getOwnPropertySymbols){var n=Object.getOwnPropertySymbols(t);e&&(n=n.filter((function(e){return Object.getOwnPropertyDescriptor(t,e).enumerable}))),r.push.apply(r,n)}return r}function r(t){for(var r=1;r<arguments.length;r++){var o=null!=arguments[r]?arguments[r]:{};r%2?e(Object(o),!0).forEach((function(e){n(t,e,o[e])})):Object.getOwnPropertyDescriptors?Object.defineProperties(t,Object.getOwnPropertyDescriptors(o)):e(Object(o)).forEach((function(e){Object.defineProperty(t,e,Object.getOwnPropertyDescriptor(o,e))}))}return t}function n(t,e,r){return e in t?Object.defineProperty(t,e,{value:r,enumerable:!0,configurable:!0,writable:!0}):t[e]=r,t}t.exports={init:function(t){var e=r({},t);return document.addEventListener("bbc-page-reset",(function(t){var r;t.detail&&t.detail.page&&(r=t.detail.page,e=Object.assign(e,r)),document.dispatchEvent(new Event("bbc-page-updated"))})),{getName:function(){return Promise.resolve(e.name||function(){if("file:"===window.location.protocol)return"local.file";var t=window.location.pathname.replace(/\/$/,"").replace(/^\//,"").replace(/\//g,".");return"".concat(t,".page")}())},getLanguage:function(){return Promise.resolve(e.language)},getDestination:function(){return Promise.resolve(e.destination)},getProducer:function(){return Promise.resolve(e.producer)},getSection:function(){return Promise.resolve(e.section)},getContentType:function(){return Promise.resolve(e.contentType)},getContentId:function(){return Promise.resolve(e.contentId)},getReferrer:function(){return Promise.resolve(document.referrer)},getAdditionalProperties:function(){return Promise.resolve(r({},e.additionalProperties))},loadCSS:function(t){return new Promise((function(e){var r=document.createElement("link");r.type="text/css",r.rel="stylesheet",r.onload=function(){e()},r.href=t,document.getElementsByTagName("head")[0].appendChild(r)}))},isModal:function(){return Promise.resolve(e.modal)}}}}},19:function(t,e,r){function n(t){return n="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(t){return typeof t}:function(t){return t&&"function"==typeof Symbol&&t.constructor===Symbol&&t!==Symbol.prototype?"symbol":typeof t},n(t)}function o(t,e){var r=Object.keys(t);if(Object.getOwnPropertySymbols){var n=Object.getOwnPropertySymbols(t);e&&(n=n.filter((function(e){return Object.getOwnPropertyDescriptor(t,e).enumerable}))),r.push.apply(r,n)}return r}function i(t){for(var e=1;e<arguments.length;e++){var r=null!=arguments[e]?arguments[e]:{};e%2?o(Object(r),!0).forEach((function(e){c(t,e,r[e])})):Object.getOwnPropertyDescriptors?Object.defineProperties(t,Object.getOwnPropertyDescriptors(r)):o(Object(r)).forEach((function(e){Object.defineProperty(t,e,Object.getOwnPropertyDescriptor(r,e))}))}return t}function c(t,e,r){return e in t?Object.defineProperty(t,e,{value:r,enumerable:!0,configurable:!0,writable:!0}):t[e]=r,t}function u(t,e){for(var r=0;r<e.length;r++){var n=e[r];n.enumerable=n.enumerable||!1,n.configurable=!0,"value"in n&&(n.writable=!0),Object.defineProperty(t,n.key,n)}}function a(t,e){if(!(t instanceof e))throw new TypeError("Cannot call a class as a function")}function f(t,e){if(e&&("object"===n(e)||"function"==typeof e))return e;if(void 0!==e)throw new TypeError("Derived constructors may only return object or undefined");return function(t){if(void 0===t)throw new ReferenceError("this hasn't been initialised - super() hasn't been called");return t}(t)}function s(t){var e="function"==typeof Map?new Map:void 0;return s=function(t){if(null===t||(r=t,-1===Function.toString.call(r).indexOf("[native code]")))return t;var r;if("function"!=typeof t)throw new TypeError("Super expression must either be null or a function");if(void 0!==e){if(e.has(t))return e.get(t);e.set(t,n)}function n(){return l(t,arguments,d(this).constructor)}return n.prototype=Object.create(t.prototype,{constructor:{value:n,enumerable:!1,writable:!0,configurable:!0}}),h(n,t)},s(t)}function l(t,e,r){return l=p()?Reflect.construct.bind():function(t,e,r){var n=[null];n.push.apply(n,e);var o=new(Function.bind.apply(t,n));return r&&h(o,r.prototype),o},l.apply(null,arguments)}function p(){if("undefined"==typeof Reflect||!Reflect.construct)return!1;if(Reflect.construct.sham)return!1;if("function"==typeof Proxy)return!0;try{return Boolean.prototype.valueOf.call(Reflect.construct(Boolean,[],(function(){}))),!0}catch(t){return!1}}function h(t,e){return h=Object.setPrototypeOf?Object.setPrototypeOf.bind():function(t,e){return t.__proto__=e,t},h(t,e)}function d(t){return d=Object.setPrototypeOf?Object.getPrototypeOf.bind():function(t){return t.__proto__||Object.getPrototypeOf(t)},d(t)}var y=r(890).loadModule,v=function(t){!function(t,e){if("function"!=typeof e&&null!==e)throw new TypeError("Super expression must either be null or a function");t.prototype=Object.create(e&&e.prototype,{constructor:{value:t,writable:!0,configurable:!0}}),Object.defineProperty(t,"prototype",{writable:!1}),e&&h(t,e)}(s,t);var e,r,n,o,i,c=(e=s,r=p(),function(){var t,n=d(e);if(r){var o=d(this).constructor;t=Reflect.construct(n,arguments,o)}else t=n.apply(this,arguments);return f(this,t)});function s(){return a(this,s),c.apply(this,arguments)}return n=s,o&&u(n.prototype,o),i&&u(n,i),Object.defineProperty(n,"prototype",{writable:!1}),n}(s(Error));t.exports={init:function(t,e){var r,n=i({},e),o=null;function c(){if(["X-Country","X-Ip_is_advertise_combined","X-Ip_is_uk_combined"].every((function(t){return!!n[t]})))return Promise.resolve(n);if(!o){var e=t.location.hostname.endsWith(".com")?"com":"co.uk";o=t.fetch("https://www.bbc.".concat(e,"/userinfo")).then((function(t){return t.json()}))}return o}function u(t){if(t.status>=200&&t.status<300)return t;var e=new Error(t.statusText);throw e.response=t,e}function a(t){return t.json()}function f(){if(n.ageBand)return Promise.resolve(n);if(!r){if("undefined"==typeof XMLHttpRequest||!("withCredentials"in new XMLHttpRequest))return Promise.resolve(n);r=y(["idcta-v2/idcta-1"]).then((function(e){return e.initiateTokenRefresh().then((function(){return t.fetch(t.orbitData.userProfileUrl,{credentials:"include"}).then(u).then(a).then((function(t){return n=i(i({},n),t)}))}))}))}return r}function s(){var t=document.cookie.match(/(?:^|; ?)ckns_policy=(\d)(\d)(\d)($|;)/);return t?{ads:!!+t[1],personalisation:!!+t[2],performance:!!+t[3],necessary:!0}:{ads:!1,personalisation:!1,performance:!1,necessary:!0}}var l={getHashedId:function(){return y(["idcta-v2/idcta-1"]).then((function(t){return t.getCookieInstance().getHidFromCookie()}))},isSignedIn:function(){return y(["idcta-v2/idcta-1"]).then((function(t){return t&&t.getCookieInstance().hasCookie()}))},getCountry:function(){return c().then((function(t){return t["X-Country"]||"gb"}))},isUKCombined:function(){return c().then((function(t){if(!t["X-Ip_is_uk_combined"])throw new v("missing isUKCombined from userinfo response");return"yes"===t["X-Ip_is_uk_combined"].toLowerCase()}))},canSeeAdverts:function(){return c().then((function(t){if(!t["X-Ip_is_advertise_combined"])throw new v("missing canSeeAdverts from userinfo response");return"yes"===t["X-Ip_is_advertise_combined"].toLowerCase()}))},getAgeBand:function(){return c().then((function(t){return t["X-Age-Band"]?Promise.resolve(t["X-Age-Band"]):l.isSignedIn().then((function(t){if(t)return f().then((function(t){return n["X-Age-Band"]=t["X-Age-Band"],n["X-Age-Band"]||void 0})).catch((function(){return n["X-Age-Band"]||void 0}))}))}))},allowsPerformanceCookies:function(){return Promise.resolve(t.navigator.cookieEnabled&&s().performance)},allowsFunctionalCookies:function(){return Promise.resolve(t.navigator.cookieEnabled&&s().personalisation)},getCookieValue:function(t){var e;return t?Promise.resolve((null===(e=document.cookie.match("(^|;)\\s*".concat(t,"\\s*=\\s*([^;]+)")))||void 0===e?void 0:e.pop())||void 0):Promise.resolve(document.cookie)}};return l},BBCUserError:v}},890:function(t){t.exports={loadModule:function(t){return new Promise((function(e,r){window.require(t,(function(){e.apply(this,arguments)}),(function(t){r(t)}))}))}}},666:function(t){var e=function(t){"use strict";var e,r=Object.prototype,n=r.hasOwnProperty,o="function"==typeof Symbol?Symbol:{},i=o.iterator||"@@iterator",c=o.asyncIterator||"@@asyncIterator",u=o.toStringTag||"@@toStringTag";function a(t,e,r){return Object.defineProperty(t,e,{value:r,enumerable:!0,configurable:!0,writable:!0}),t[e]}try{a({},"")}catch(t){a=function(t,e,r){return t[e]=r}}function f(t,e,r,n){var o=e&&e.prototype instanceof v?e:v,i=Object.create(o.prototype),c=new k(n||[]);return i._invoke=function(t,e,r){var n=l;return function(o,i){if(n===h)throw new Error("Generator is already running");if(n===d){if("throw"===o)throw i;return C()}for(r.method=o,r.arg=i;;){var c=r.delegate;if(c){var u=_(c,r);if(u){if(u===y)continue;return u}}if("next"===r.method)r.sent=r._sent=r.arg;else if("throw"===r.method){if(n===l)throw n=d,r.arg;r.dispatchException(r.arg)}else"return"===r.method&&r.abrupt("return",r.arg);n=h;var a=s(t,e,r);if("normal"===a.type){if(n=r.done?d:p,a.arg===y)continue;return{value:a.arg,done:r.done}}"throw"===a.type&&(n=d,r.method="throw",r.arg=a.arg)}}}(t,r,c),i}function s(t,e,r){try{return{type:"normal",arg:t.call(e,r)}}catch(t){return{type:"throw",arg:t}}}t.wrap=f;var l="suspendedStart",p="suspendedYield",h="executing",d="completed",y={};function v(){}function g(){}function b(){}var m={};a(m,i,(function(){return this}));var w=Object.getPrototypeOf,O=w&&w(w(S([])));O&&O!==r&&n.call(O,i)&&(m=O);var P=b.prototype=v.prototype=Object.create(m);function j(t){["next","throw","return"].forEach((function(e){a(t,e,(function(t){return this._invoke(e,t)}))}))}function E(t,e){function r(o,i,c,u){var a=s(t[o],t,i);if("throw"!==a.type){var f=a.arg,l=f.value;return l&&"object"==typeof l&&n.call(l,"__await")?e.resolve(l.__await).then((function(t){r("next",t,c,u)}),(function(t){r("throw",t,c,u)})):e.resolve(l).then((function(t){f.value=t,c(f)}),(function(t){return r("throw",t,c,u)}))}u(a.arg)}var o;this._invoke=function(t,n){function i(){return new e((function(e,o){r(t,n,e,o)}))}return o=o?o.then(i,i):i()}}function _(t,r){var n=t.iterator[r.method];if(n===e){if(r.delegate=null,"throw"===r.method){if(t.iterator.return&&(r.method="return",r.arg=e,_(t,r),"throw"===r.method))return y;r.method="throw",r.arg=new TypeError("The iterator does not provide a 'throw' method")}return y}var o=s(n,t.iterator,r.arg);if("throw"===o.type)return r.method="throw",r.arg=o.arg,r.delegate=null,y;var i=o.arg;return i?i.done?(r[t.resultName]=i.value,r.next=t.nextLoc,"return"!==r.method&&(r.method="next",r.arg=e),r.delegate=null,y):i:(r.method="throw",r.arg=new TypeError("iterator result is not an object"),r.delegate=null,y)}function x(t){var e={tryLoc:t[0]};1 in t&&(e.catchLoc=t[1]),2 in t&&(e.finallyLoc=t[2],e.afterLoc=t[3]),this.tryEntries.push(e)}function L(t){var e=t.completion||{};e.type="normal",delete e.arg,t.completion=e}function k(t){this.tryEntries=[{tryLoc:"root"}],t.forEach(x,this),this.reset(!0)}function S(t){if(t){var r=t[i];if(r)return r.call(t);if("function"==typeof t.next)return t;if(!isNaN(t.length)){var o=-1,c=function r(){for(;++o<t.length;)if(n.call(t,o))return r.value=t[o],r.done=!1,r;return r.value=e,r.done=!0,r};return c.next=c}}return{next:C}}function C(){return{value:e,done:!0}}return g.prototype=b,a(P,"constructor",b),a(b,"constructor",g),g.displayName=a(b,u,"GeneratorFunction"),t.isGeneratorFunction=function(t){var e="function"==typeof t&&t.constructor;return!!e&&(e===g||"GeneratorFunction"===(e.displayName||e.name))},t.mark=function(t){return Object.setPrototypeOf?Object.setPrototypeOf(t,b):(t.__proto__=b,a(t,u,"GeneratorFunction")),t.prototype=Object.create(P),t},t.awrap=function(t){return{__await:t}},j(E.prototype),a(E.prototype,c,(function(){return this})),t.AsyncIterator=E,t.async=function(e,r,n,o,i){void 0===i&&(i=Promise);var c=new E(f(e,r,n,o),i);return t.isGeneratorFunction(r)?c:c.next().then((function(t){return t.done?t.value:c.next()}))},j(P),a(P,u,"Generator"),a(P,i,(function(){return this})),a(P,"toString",(function(){return"[object Generator]"})),t.keys=function(t){var e=[];for(var r in t)e.push(r);return e.reverse(),function r(){for(;e.length;){var n=e.pop();if(n in t)return r.value=n,r.done=!1,r}return r.done=!0,r}},t.values=S,k.prototype={constructor:k,reset:function(t){if(this.prev=0,this.next=0,this.sent=this._sent=e,this.done=!1,this.delegate=null,this.method="next",this.arg=e,this.tryEntries.forEach(L),!t)for(var r in this)"t"===r.charAt(0)&&n.call(this,r)&&!isNaN(+r.slice(1))&&(this[r]=e)},stop:function(){this.done=!0;var t=this.tryEntries[0].completion;if("throw"===t.type)throw t.arg;return this.rval},dispatchException:function(t){if(this.done)throw t;var r=this;function o(n,o){return u.type="throw",u.arg=t,r.next=n,o&&(r.method="next",r.arg=e),!!o}for(var i=this.tryEntries.length-1;i>=0;--i){var c=this.tryEntries[i],u=c.completion;if("root"===c.tryLoc)return o("end");if(c.tryLoc<=this.prev){var a=n.call(c,"catchLoc"),f=n.call(c,"finallyLoc");if(a&&f){if(this.prev<c.catchLoc)return o(c.catchLoc,!0);if(this.prev<c.finallyLoc)return o(c.finallyLoc)}else if(a){if(this.prev<c.catchLoc)return o(c.catchLoc,!0)}else{if(!f)throw new Error("try statement without catch or finally");if(this.prev<c.finallyLoc)return o(c.finallyLoc)}}}},abrupt:function(t,e){for(var r=this.tryEntries.length-1;r>=0;--r){var o=this.tryEntries[r];if(o.tryLoc<=this.prev&&n.call(o,"finallyLoc")&&this.prev<o.finallyLoc){var i=o;break}}i&&("break"===t||"continue"===t)&&i.tryLoc<=e&&e<=i.finallyLoc&&(i=null);var c=i?i.completion:{};return c.type=t,c.arg=e,i?(this.method="next",this.next=i.finallyLoc,y):this.complete(c)},complete:function(t,e){if("throw"===t.type)throw t.arg;return"break"===t.type||"continue"===t.type?this.next=t.arg:"return"===t.type?(this.rval=this.arg=t.arg,this.method="return",this.next="end"):"normal"===t.type&&e&&(this.next=e),y},finish:function(t){for(var e=this.tryEntries.length-1;e>=0;--e){var r=this.tryEntries[e];if(r.finallyLoc===t)return this.complete(r.completion,r.afterLoc),L(r),y}},catch:function(t){for(var e=this.tryEntries.length-1;e>=0;--e){var r=this.tryEntries[e];if(r.tryLoc===t){var n=r.completion;if("throw"===n.type){var o=n.arg;L(r)}return o}}throw new Error("illegal catch attempt")},delegateYield:function(t,r,n){return this.delegate={iterator:S(t),resultName:r,nextLoc:n},"next"===this.method&&(this.arg=e),y}},t}(t.exports);try{regeneratorRuntime=e}catch(t){"object"==typeof globalThis?globalThis.regeneratorRuntime=e:Function("r","regeneratorRuntime = r")(e)}}},e={};function r(n){var o=e[n];if(void 0!==o)return o.exports;var i=e[n]={exports:{}};return t[n](i,i.exports,r),i.exports}r(666);r(930)}();</script>

<script type="module">
    window.importmap = {"orbit-drawer":"https://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/js/drawer.mjs","bbccookies":"https://static.files.bbci.co.uk/cookies/d3bb303e79f041fec95388e04f84e716/cookie-banner/cookie-library.module.js"};
    var o={738:function(o){o.exports={loadModule:function(o){return new Promise(((n,t)=>{window.require(o,(function(){n.apply(this,arguments)}),(o=>{t(o)}))}))}}},61:function(o,n,t){const{loadModule:r}=t(738);o.exports=function(o){return function(n){return"string"==typeof n&&o[n]?import(o[n]):r(n)}}}},n={};function t(r){var i=n[r];if(void 0!==i)return i.exports;var e=n[r]={exports:{}};return o[r](e,e.exports,t),e.exports}!function(){const o=t(61);window.shimport=o({...window.importmap}),window.importMap=void 0}();</script>

<script type="text/javascript">
    window.page = undefined;
    window.user = undefined;
</script>

<link rel="preload" href="https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Rg.woff2" as="font" type="font/woff2" crossorigin>
<link rel="preload" href="https://static.files.bbci.co.uk/fonts/reith/2.512/BBCReithSans_W_Bd.woff2" as="font" type="font/woff2" crossorigin>

    
    <!-- searchbox Web Module: 3.1.0-606.ecf693f -->
    
    
    <!-- navpromo Web Module: 3.0.1-51.ec476ab -->
    
    
    <!-- cookies Web Module: 0.0.4-99.b372a0f -->
    
    
    <!-- useractivityhelper Web Module: 1.0.0-293.bd5178e -->
    
    
    <!-- reverb Web Module: 3.6.1 -->
    
    
    <!-- ukomtracking Web Module: 1.1.0 -->
    
    
    <!-- idcta Web Module:  -->
    
    
    <!-- notifications Web Module: 5.0.19 -->
    

    
<link rel="stylesheet" href="https://nav.files.bbci.co.uk/searchbox/c8bfe8595e453f2b9483fda4074e9d15/css/box.css">

    
    
    
    
    
         <script src="https://static.files.bbci.co.uk/cookies/d3bb303e79f041fec95388e04f84e716/cookie-banner/cookie-library.bundle.js"></script><script type="text/javascript">void 0!==window.define&&define("orb/cookies",function(){return window.bbccookies})</script>  
    
    
    <script type='text/javascript'>window.__detectview={clickManagementEnabled:false};</script>
    
    
    <script type="text/javascript">"use strict";!function(){window.__reverbStaticLocation="https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/",window.__smarttagVersion="5.29.4",window.__reverb={},window.__reverb.__reverbLoadedPromise=new Promise(function(e,i){window.__reverb.__resolveReverbLoaded=e,window.__reverb.__rejectReverbLoaded=i}),window.__reverb.__reverbTimeout=setTimeout(function(){window.__reverb.__rejectReverbLoaded()},5e3);var i=function(d,a){window.__reverb.__reverbLoadedPromise.then(function(e){if(d&&d.detail){var i=!!d.detail.item,n=d.detail.label,t=i?"viewability":d.detail.type,o=d.detail.elem,r=d.detail.originalEvent;d.detail.isClick&&(a=d.detail.isClick),e.userActionEvent(t,n,d.detail,o,r,a)}},function(){console.log("Reverb failed to load. Event not sent")})},n=function(){window.__reverb.__reverbLoadedPromise.then(function(e){e.initialise().then(function(){return e.viewEvent()})},function(){console.log("Reverb failed to load. Event not sent")})};document.addEventListener("bbc-user-event",function(e){i(e,!1)}),document.addEventListener("bbc-user-click",function(e){i(e,!0)}),document.addEventListener("bbc-page-updated",n),window.addEventListener("pageshow",function(e){e.persisted&&n()})}();</script><script type='text/javascript' src='https://mybbc-analytics.files.bbci.co.uk/reverb-client-js/reverb-3.6.1.js' async></script>
    
    
    <script type="text/javascript">"use strict";function asyncGeneratorStep(e,t,n,r,o,a,i){try{var s=e[a](i),c=s.value}catch(e){return void n(e)}s.done?t(c):Promise.resolve(c).then(r,o)}function _asyncToGenerator(s){return function(){var e=this,i=arguments;return new Promise(function(t,n){var r=s.apply(e,i);function o(e){asyncGeneratorStep(r,t,n,o,a,"next",e)}function a(e){asyncGeneratorStep(r,t,n,o,a,"throw",e)}o(void 0)})}}var wrapMethod=function(e,t){return e[t]&&"function"==typeof e[t]?e[t]():Promise.resolve(null)},getPageVariables=function(){return window&&window.bbcpage?Promise.all(["getDestination","getSection","getProducer"].map(function(e){return wrapMethod(window.bbcpage,e)})).then(function(e){var t=JSON.parse(JSON.stringify(e));return{destination:t[0],section:t[1],producer:t[2]}}):Promise.resolve(void 0)},getUserVariables=function(){return window&&window.bbcuser?Promise.all(["isSignedIn","getHashedId"].map(function(e){return wrapMethod(window.bbcuser,e)})).then(function(e){var t=JSON.parse(JSON.stringify(e));return{isSignedIn:t[0],hashedId:t[1]}}):Promise.resolve(void 0)},dotMetricsTag=function(e,t){var n=document.createElement("script");return n.src="https://uk-script.dotmetrics.net/door.js?d=".concat(t,"&t=").concat(e),n.async=!0,n.id="dotmetrics",document.body.appendChild(n),function(){document.body.removeChild(n)}},isAccountPage=function(e,t){return!!e.includes("account.bbc")||!!t&&("account"===t.toLowerCase()||"account_test"===t.toLowerCase())},parseSiteSectionName=function(e){var t=e.destination,n=e.section,r=e.producer,o=document?document.location.host.replace(/:.*/,""):"bbc.no.host";if(t){var a="";n&&["NEWS_PS","NEWS_PS_TEST","SOUNDS","SOUNDS_TEST","SPORT_PS","SPORT_PS_TEST","IPLAYER","IPLAYER_TEST"].includes(t.toUpperCase())&&(a=n.split("::")[0]);return r&&["FEATURE_SITES_GNL","FEATURE_SITES_GNL_TEST"].includes(t.toUpperCase())&&(t=r),{siteSectionNameString:"".concat(t).concat(a).toLowerCase().replace(/_/g,""),host:o}}return{siteSectionNameString:"other",host:o}};function startUkom(){return _startUkom.apply(this,arguments)}function _startUkom(){return(_startUkom=_asyncToGenerator(regeneratorRuntime.mark(function e(){var t,n,r;return regeneratorRuntime.wrap(function(e){for(;;)switch(e.prev=e.next){case 0:return e.next=2,getUserVariables();case 2:if((t=e.sent)&&t.isSignedIn&&null==t.hashedId)return e.abrupt("return");e.next=5;break;case 5:return e.next=7,getPageVariables();case 7:if(n=e.sent,isAccountPage(document.location.host,n.destination))return e.abrupt("return");e.next=10;break;case 10:r=parseSiteSectionName(n),dotMetricsTag(r.siteSectionNameString,r.host);case 12:case"end":return e.stop()}},e)}))).apply(this,arguments)}document.addEventListener("bbc-page-updated",function(){startUkom()}),window.addEventListener("pageshow",function(e){e.persisted&&startUkom()}),document.addEventListener("DOMContentLoaded",function(){startUkom()});</script>
    
    
    <link rel="stylesheet" href="https://static.files.bbci.co.uk/account/id-cta/594/style/id-cta.css"><script type="text/javascript">(function () {if (!window.require) {throw new Error('idcta: could not find require module');}if (typeof (map) == 'undefined') {var map = {};}if (!!document.createElementNS && !!document.createElementNS('http://www.w3.org/2000/svg', 'svg').createSVGRect) {document.documentElement.className += ' id-svg';}var ptrt = new RegExp("[\\?&]ptrt=([^&]*)").exec(document.location.href);var ENDPOINT_URL = 'https://idcta.api.bbc.co.uk';var ENDPOINT_CONFIG = ('/idcta/config?callback=&ptrt=' + (ptrt ? ptrt[1] : encodeURIComponent(document.location.href))).replace(/\&amp;/g, '&');var ENDPOINT_TRANSLATIONS = '/idcta/translations?callback=';function hasPromise() {var P = window.Promise;var promiseToString = null;if (P) {try {promiseToString = Object.prototype.toString.call(P.resolve());} catch (e) {/*silently ignored*/}}return (promiseToString === '[object Promise]' && !P.cast);}if (hasPromise()) {define('idcta/es6-promise', function () {return window.Promise;});define('idcta-v2/es6-promise', function () {return window.Promise;});}map['idcta-v2'] = 'https://static.files.bbci.co.uk/account/id-cta/594/modules/idcta-v2';map['idcta-v2/config'] = ENDPOINT_URL + ENDPOINT_CONFIG;map['idcta-v2/translations'] = ENDPOINT_URL + ENDPOINT_TRANSLATIONS;map['idcta'] = 'https://static.files.bbci.co.uk/account/id-cta/1.8.2/modules/idcta';map['idcta-v2/idcta-1'] = 'https://static.files.bbci.co.uk/account/id-cta/594/modules/idcta-v2/dist/idcta-1.min';map['idcta-v2/experiment-snippet'] = 'https://cdn.optimizely.com/public/4621041136/s/idcta_live';const idctaShim = {deps: ['idcta-v2/idcta-1'],};require({shim: {'idcta-v2/statusbar': idctaShim,'idcta-v2/id-config': idctaShim},map: {'*': {'idcta/idcta-1': 'idcta-v2/idcta-1','idcta': 'idcta-v2',}},paths: map});window.idctaBaseUrl = ENDPOINT_URL;define('idcta/config', ['idcta-v2/config'], function (data) { return data; });define('idcta/translations', ['idcta-v2/translations'], function (data) { return data; });})();</script>
    
    
    
    
	<!--[if lte IE 8]><script src="https://static.live.bbc.co.uk/bbcle/0.2.66/script/excanvas.js"></script><![endif]-->
<script>
(function(){
	require({
		paths: {
			"bump-3": "https:\/\/emp.bbci.co.uk\/emp\/bump-3\/bump-3",
			/* Defining the path to jQuery UI (Custom) or this project. Custom version which only contains core elements, draggable, droppable and sortable */
			/* Using minified version */
			"jquery-ui-1": "https:\/\/static.live.bbc.co.uk\/bbcle\/0.2.66\/script\/jquery-ui-1.4.10.min"	    },
    	waitSeconds: 30
    });
})();
</script>


<meta name="google-site-verification" content="DFGX-ewPjIG4aHQXtYY6QAwePhYe7tMNrmMIJT1HNgk" />

<meta name="description" content="Get up-to-date with the latest news and understand it too with Lingohack. Listen to and watch authentic BBC news bulletins and learn key words and phrases that help you make sense of the news." />

<meta property="og:title" content="BBC Learning English - Lingohack " />
<meta property="og:type" content="article" />
<meta property="og:description" content="Get up-to-date with the latest news and understand it too with Lingohack. Listen to and watch authentic BBC news bulletins and learn key words and phrases that help you make sense of the news." />
<meta property="og:site_name" content="BBC Learning English" />
<meta property="og:locale" content="en_GB" />
<meta property="article:author" content="BBC Learning English" />
<meta property="og:url" content="https://www.bbc.co.uk//learningenglish/english/features/lingohack_2022" />
<meta property="og:image" content="https://ichef.bbci.co.uk/images/ic/1200xn/p0c4zwqs.jpg" />


<meta name="twitter:card" content="summary_large_image">
<meta name="twitter:site" content="@BBCle">
<meta name="twitter:title" content="BBC Learning English - Lingohack ">
<meta name="twitter:description" content="Get up-to-date with the latest news and understand it too with Lingohack. Listen to and watch authentic BBC news bulletins and learn key words and phrases that help you make sense of the news.">
<meta name="twitter:creator" content="@BBCle">
<meta name="twitter:image:src" content="https://ichef.bbci.co.uk/images/ic/592xn/p0c4zwqs.jpg">
<meta name="twitter:image:alt" content="" />
<meta name="twitter:domain" content="www.bbc.co.uk" />

<script type="application/ld+json">
{"@context":"http:\/\/schema.org","@type":"Article","author":{"@type":"Organization","name":"BBC Learning English"},"publisher":{"@type":"Organization","name":"BBC Learning English","logo":{"@type":"ImageObject","url":"http:\/\/news.files.bbci.co.uk\/amp\/bbc_news_black_60px.png"}},"headline":"BBC Learning English - Lingohack ","datePublished":"2022-12-15T17:16:00+00:00","image":{"@type":"ImageObject","url":"https:\/\/ichef.bbci.co.uk\/images\/ic\/1200xn\/p0c4zwqs.jpg","height":"","width":""}}</script>

	<link rel="stylesheet" href="https://static.live.bbc.co.uk/bbcle/0.2.66/style/bbcle.css">
	<script>require({paths:{"jquery-1":"//static.stage.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.7.2"}});</script>
</head>
<body class="bbcle-features bbcle-features-lingohack_2022">
<noscript><p style="position: absolute; top: -999em"><img src="https://a1.api.bbc.co.uk/hit.xiti?&col=1&from=p&ptag=js&s=598253&p=learningenglish.features.lingohack_2022.page&x2=[responsive]&x3=[bbc_website]&x4=[en]&x7=[index-section]&x8=[reverb-3.6.1-nojs]&x11=[WS_LEARNING_ENGLISH]&x12=[WS_LEARNING_ENGLISH]" height="1" width="1" alt=""></p></noscript>  <div class="orbit-header-container" id="orbit-header"><header id="orb-banner" role="banner" aria-label="BBC-wide" class="orbit-header geo orbit-default orbit-language-en orbit-ux-v5"><div id="orb-header" class="orb-nav-pri orb-nav-pri-white orb-nav-empty" dir="ltr"><div class="orb-nav-pri-container b-r b-g-p"><div class="orb-nav-section orb-nav-blocks"><a href="https://www.bbc.co.uk" id="homepage-link"><svg width="112" height="32" viewbox="0 0 112 32" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M8.99999 6.99999H15.7552C17.7458 6.99999 19.2878 7.39887 20.3811 8.19576C21.4741 8.99309 22.021 10.1385 22.021 11.6321C22.021 12.4881 21.8252 13.2308 21.4335 13.8601C21.0419 14.4894 20.4625 14.9891 19.6958 15.358C20.7563 15.7104 21.5682 16.2686 22.1311 17.0321C22.6941 17.796 22.9755 18.7232 22.9755 19.814C22.9755 20.8882 22.7021 21.8114 22.1555 22.5832C21.6087 23.3553 20.8296 23.9513 19.8182 24.3706C18.8062 24.7903 17.5909 25 16.1713 25H8.99999V6.99999ZM0 32H32V0H0V32ZM48.9999 6.99999H55.7551C57.7457 6.99999 59.2877 7.39887 60.3811 8.19576C61.4741 8.99309 62.0209 10.1385 62.0209 11.6321C62.0209 12.4881 61.8251 13.2308 61.4334 13.8601C61.0419 14.4894 60.4624 14.9891 59.6957 15.358C60.7562 15.7104 61.568 16.2686 62.1311 17.0321C62.694 17.796 62.9753 18.7232 62.9753 19.814C62.9753 20.8882 62.7019 21.8114 62.1554 22.5832C61.6087 23.3553 60.8297 23.9513 59.818 24.3706C58.8062 24.7903 57.5908 25 56.1712 25H48.9999V6.99999ZM39.9999 32H71.9999V0H39.9999V32ZM55.8775 17.2209H52.6469V22.0797H55.8286C56.9216 22.0797 57.7622 21.8743 58.3497
class="orb-nav-traveldotcom"><a href="https://www.bbc.com/travel"><span>Travel</span></a></li><li class="orb-nav-future"><a href="https://www.bbc.com/future"><span>Future</span></a></li><li class="orb-nav-culture"><a href="https://www.bbc.com/culture"><span>Culture</span></a></li><li class="orb-nav-tv"><a href="https://www.bbc.co.uk/schedules/p00fzl9m"><span>TV</span></a></li><li class="orb-nav-weather"><a href="https://www.bbc.com/weather"><span>Weather</span></a></li><li class="orb-nav-sounds"><a href="https://www.bbc.co.uk/sounds"><span>Sounds</span></a></li></ul></nav><div class="orbit-header-right"><a aria-label="All BBC destinations menu" class="orbit-header-more" href="#orbit-more-drawer" id="orbit-more-button"><svg class="orbit-header-more-desktop" width="20" height="4" viewbox="0 0 20 4" version="1.1" xmlns="http://www.w3.org/2000/svg"><g id="Overflow" transform="translate(-14.000000, -22.000000)"><path d="M18,22 L18,26 L14,26 L14,22 L18,22 Z M34,22 L34,26 L30,26 L30,22 L34,22 Z M26,22 L26,26 L22,26 L22,22 L26,22 Z" id="More"></path></g></svg><svg class="orbit-header-more-mobile" width="24" height="22" viewbox="0 0 20 19" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M0 3.63393H20V0H0V3.63393ZM0 10.9018H20V7.26787H0V10.9018ZM0 18.5H20V14.8661H0V18.5Z"></svg><span class="orbit-button-text">More menu</span></a><div class="orb-nav-section orb-nav-search" role="search">  <a id="orbit-search-button" class="orbit-search__button" aria-expanded="false" href="https://search.bbc.co.uk/search?scope=bbcle&destination=WS_LEARNING_ENGLISH" title="Search BBC"><span class="ux-v4">Search BBC</span> <span class="ux-v5"><svg class="orbit-search-button-icon-only" width="28" height="29" viewbox="0 0 28 29" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M11,-0.0001 C17.0751322,-0.0001 22,4.92476775 22,10.9999 C22,13.5276632 21.1473793,15.8562862 19.7140404,17.7138664 L28,26 L25,29 L16.518046,20.5178339 C14.8960209,21.4602385 13.0110328,21.9999 11,21.9999 C4.92486775,21.9999 0,17.0750322 0,10.9999 C0,4.92476775 4.92486775,-0.0001 11,-0.0001 Z M11,2.5 C6.30557963,2.5 2.5,6.30557963 2.5,11 C2.5,15.6944204 6.30557963,19.5 11,19.5 C15.6944204,19.5 19.5,15.6944204 19.5,11 C19.5,6.30557963 15.6944204,2.5 11,2.5 Z"></path></svg><svg class="orbit-search-button-icon-with-text" width="15" height="16" viewbox="0 0 15 16" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M6,-5.32907052e-15 C9.3137085,-5.32907052e-15 12,2.6862915 12,6 C12,7.43892143 11.4934776,8.75953821 10.6490096,9.79327337 L15,14.24 L13.2782609,16 L8.72578477,11.3465317 C7.90789326,11.7643456 6.98146665,12 6,12 C2.6862915,12 -1.687539e-14,9.3137085 -1.687539e-14,6 C-1.687539e-14,2.6862915 2.6862915,-5.32907052e-15 6,-5.32907052e-15 Z M6,1.5 C3.51471863,1.5 1.5,3.51471863 1.5,6 C1.5,8.48528137 3.51471863,10.5 6,10.5 C8.48528137,10.5 10.5,8.48528137 10.5,6 C10.5,3.51471863 8.48528137,1.5 6,1.5 Z"></path></svg><span>Search
span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/course/test-your-level" class="">Test Your Level<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/downloads" class="">Downloads<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/classroom_teaching" class="">Teachers<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/features/childrens-stories" class="">For Children<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/podcasts" class="">Podcasts<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/features/drama" class="">Drama<span class="hide parent-item-text">More...</span></a></li><li><a href="/learningenglish/english/app" class="">Our App<span class="hide parent-item-text">More...</span></a></li></ul></li><li><a href="#" id="select-language-link" data-nav-index="navIndex-" class="menu-internal-dropdown"><span class="current-language">English</span> Change Language</a><ul id="language-selections"><li class="active"><a lang="en" href="/learningenglish/english/features/lingohack_2022">English</a></li><li class=""><a lang="fa" href="/learningenglish/persian/features/lingohack_2022">فارسی</a></li><li class=""><a lang="zh" href="/learningenglish/chinese/features/lingohack_2022">中文</a></li><li class=""><a lang="th" href="/learningenglish/thai/features/lingohack_2022">ไทย</a></li><li class=""><a lang="my" href="/learningenglish/burmese/features/lingohack_2022">ဗမာစာ</a></li><li class=""><a lang="ko" href="/learningenglish/korean/features/lingohack_2022">한국어</a></li><li class=""><a lang="am" href="/learningenglish/amharic/features/lingohack_2022">አማርኛ</a></li><li class=""><a lang="om" href="/learningenglish/oromo/features/lingohack_2022">Afaan Oromoo</a></li><li class=""><a lang="ti" href="/learningenglish/tigrinya/features/lingohack_2022">ትግርኛ</a></li></ul></li><li class="show-group-a"><div><form action="/learningenglish/english/search" method="get"><input type="search" name="q" value="" placeholder="Search term"><input type="submit" name="submit" value="GO"></form></div></li></ul></div> </div> </div> </div> <!-- END OF bbcle-header --> <div class="bbc-le-nav-wrapper"> <div id="bbcle-header-nav" class="translated-nav"><div class="content-no-sidebar b-g-p" ><a href="#navIndex-0" data-nav-index="navIndex-0" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">Courses</a><a href="#navIndex-1" data-nav-index="navIndex-1" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">Grammar</a><a href="#navIndex-2" data-nav-index="navIndex-2" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">Pronunciation</a><a href="#navIndex-3" data-nav-index="navIndex-3" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">Vocabulary</a><a href="#navIndex-4" data-nav-index="navIndex-4" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">News</a><a href="#navIndex-5" data-nav-index="navIndex-5" class=" bbcle-expandable-nav-button bbcle-nav-button" data-nosynd="1">More...</a><div class="bbcle-nav-controls"><a data-nav-index="navIndex-search" class="bbcle-expandable-nav-button bbcle-nav-search bbcle-nav-button  " data-nosynd="1" href="#navIndex-search"><span  data-i18n-message-id="Search" class="not-translated _bbcle_translate_wrapper" lang="en">Search</span></a></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-0"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/easy_course">Easy Courses<span class="hide parent-item-text">Courses</span></a></li><li><a class="" href="/learningenglish/english/medium_course">Medium Courses<span class="hide parent-item-text">Courses</span></a></li><li><a class="" href="/learningenglish/english/hard_course">Hard Courses<span class="hide parent-item-text">Courses</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-1"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/easy_grammar">Easy Grammar<span class="hide parent-item-text">Grammar</span></a></li><li><a class="" href="/learningenglish/english/medium_grammar">Medium Grammar<span class="hide parent-item-text">Grammar</span></a></li><li><a class="" href="/learningenglish/english/hard_grammar">Hard Grammar<span class="hide parent-item-text">Grammar</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-2"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/easy_pronunciation">Easy Pronunciation<span class="hide parent-item-text">Pronunciation</span></a></li><li><a class="" href="/learningenglish/english/medium_pronunciation">Medium Pronunciation<span class="hide parent-item-text">Pronunciation</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-3"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/easy_vocabulary">Easy Vocabulary<span class="hide parent-item-text">Vocabulary</span></a></li><li><a class="" href="/learningenglish/english/medium_vocabulary">Medium Vocabulary<span class="hide parent-item-text">Vocabulary</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-4"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/course/newsreview-2022">News Review<span class="hide parent-item-text">News</span></a></li><li><a class="" href="/learningenglish/english/course/newsreview">News Review Archive<span class="hide parent-item-text">News</span></a></li><li><a class="" href="/learningenglish/english/course/fakenews">Fake News Archive<span class="hide parent-item-text">News</span></a></li><li><a class="current" href="/learningenglish/english/features/lingohack_2022">Lingohack Archive<span class="hide parent-item-text">News</span></a></li><li><a class="" href="/learningenglish/english/features/englishinthenews">English in the News  Archive<span class="hide parent-item-text">News</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list" id="navIndex-5"><div class="content-no-sidebar b-g-p"><ul><li><a class="" href="/learningenglish/english/course/quizzes/unit-1">Quizzes<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/course/test-your-level">Test Your Level<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/downloads">Downloads<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/classroom_teaching">Teachers<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/features/childrens-stories">For Children<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/podcasts">Podcasts<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/features/drama">Drama<span class="hide parent-item-text">More...</span></a></li><li><a class="" href="/learningenglish/english/app">Our App<span class="hide parent-item-text">More...</span></a></li></ul></div></div><div class="bbcle-expandable-nav bbcle-course-nav-list " id="navIndex-search"><div class="content-no-sidebar b-g-p"><form action="/learningenglish/english/search" method="get"><input type="search" name="q" value="" placeholder="Search term"><input type="submit" name="submit" value="GO"></form></div></div></div> </div> <div id="bbcle-content" class="content-no-sidebar b-g-p"> <div role="article"> <div class="widget-container widget-container-left" data-widget-section-index="0">		<div id="heading-lingohack-" class="widget widget-heading"  data-widget-index="1"><h3  dir="ltr" >Lingohack </h3></div>
		<div id="heading-intermediate-level" class="widget widget-heading"  data-widget-index="2"><h4  dir="ltr" >Intermediate level</h4></div>
<div class="widget widget-richtext 3"><div class="text" dir="ltr"><p>Get up-to-date with the latest news and understand it too with Lingohack. Listen to and watch authentic BBC World news bulletins and learn key words and phrases that help you make sense of the news.</p>
<p>For programmes from before 2022, visit our&nbsp;<strong><a href="https://www.bbc.co.uk/learningenglish/english/features/lingohack">Lingohack archive</a></strong></p></div></div></div><div class="widget-container widget-container-right" data-widget-section-index="1"></div><div class="widget-container widget-container-full" data-widget-section-index="2">
<div class="widget widget-bbcle-coursecontentlist widget-bbcle-coursecontentlist-featured widget-progress-enabled" data-widget-index="4">
			<div data-feature-item="/features/lingohack_2022/ep-220525" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220525"><img src="https://ichef.bbci.co.uk/images/ic/976xn/p0c4zwqs.jpg" id="1_p0c4zwqs" data-type="image" data-pid="p0c4zwqs" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/976xn/p0c4zwqs.jpg 976w,https://ichef.bbci.co.uk/images/ic/1920xn/p0c4zwqs.jpg 1952w" width="976" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220525">Flying car</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220525 </b>
							 
				 / 				  25 May 2022						</h3>
		<p>Language related to retail: model, processing, licensed, orders, bring (something) to market.</p>
	</div>
</div>
</div>
<div class="widget widget-bbcle-coursecontentlist widget-bbcle-coursecontentlist-standard widget-progress-enabled" data-widget-index="5">
<ul class="threecol">
				<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220511" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220511"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0b023bk.jpg" id="1_p0b023bk" data-type="image" data-pid="p0b023bk" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0b023bk.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0b023bk.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220511">Pigs on patrol</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220511 </b>
							 
				 / 				  11 May 2022						</h3>
		<p>Learn language related to farming: scarecrow, harvest, crop, soil, fertile</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220504" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220504"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0bfgtgq.jpg" id="1_p0bfgtgq" data-type="image" data-pid="p0bfgtgq" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0bfgtgq.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0bfgtgq.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220504">‘Extinct’ fish returns to the wild</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220504 </b>
							 
				 / 				  04 May 2022						</h3>
		<p>Learn language related to disappearing and reappearing: missing, under the radar, bringing (something) back, recovering, making a comeback</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220427" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220427"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0bvqcqm.jpg" id="1_p0bvqcqm" data-type="image" data-pid="p0bvqcqm" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0bvqcqm.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0bvqcqm.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220427">Endurance: Shackleton's lost ship is found in Antarctic</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220427 </b>
							 
				 / 				  27 Apr 2022						</h3>
		<p>Learn language related to shipwrecks: preserved, construction, pristine, portholes, raised </p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220420" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220420"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0c1521g.jpg" id="1_p0c1521g" data-type="image" data-pid="p0c1521g" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0c1521g.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0c1521g.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220420">How to make people like robots</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220420 </b>
							 
				 / 				  20 Apr 2022						</h3>
		<p>Learn language related to behaviour: playful, curious, sociable, interact, accept</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220413" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220413"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0bzmy2v.jpg" id="1_p0bzmy2v" data-type="image" data-pid="p0bzmy2v" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0bzmy2v.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0bzmy2v.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220413">Hope for people with diabetes</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220413 </b>
							 
				 / 				  13 Apr 2022						</h3>
		<p>Learn vocabulary related to medical treatment: trial, monitors, game changer, quality of life, stabilised.</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220406" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220406"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0byb42y.jpg" id="1_p0byb42y" data-type="image" data-pid="p0byb42y" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0byb42y.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0byb42y.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220406">First woman of colour completes a solo expedition across Antarctica</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220406 </b>
							 
				 / 				  06 Apr 2022						</h3>
		<p>Learn language related to physical challenges: comfort zone, gruelling, toughest, reservations, hardships
</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220330" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220330"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0bwzm7k.jpg" id="1_p0bwzm7k" data-type="image" data-pid="p0bwzm7k" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0
jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0bb6l4l.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220112">Robotic surgery</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220112 </b>
							 
				 / 				  12 Jan 2022						</h3>
		<p>Learn language related to surgery: operation, medical field, patient, surgeons, keyhole surgery 
</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-220105" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-220105"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p09skjj2.jpg" id="1_p09skjj2" data-type="image" data-pid="p09skjj2" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p09skjj2.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p09skjj2.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-220105">Protecting seahorses</a></h2>
	<div class="details">
		<h3>
																<b>Episode 220105 </b>
							 
				 / 				  05 Jan 2022						</h3>
		<p>Learn language related to sea and boats: teeming with (life), mooring chains, seabed, tide, seafarers</p>
	</div>
</div>
</li>
			<li class="course-content-item active">			<div data-feature-item="/features/lingohack_2022/ep-180522" class="progress-enabled completed hide"><span  data-i18n-message-id="completed" class="not-translated _bbcle_translate_wrapper" lang="en">completed</span></div>
	<div class="img">
	<a  href="/learningenglish/english/features/lingohack_2022/ep-180522"><img src="https://ichef.bbci.co.uk/images/ic/624xn/p0c252pt.jpg" id="1_p0c252pt" data-type="image" data-pid="p0c252pt" data-title="" data-description="" srcset="https://ichef.bbci.co.uk/images/ic/624xn/p0c252pt.jpg 624w,https://ichef.bbci.co.uk/images/ic/1248xn/p0c252pt.jpg 1248w" width="624" alt="" /></a>	
</div>
<div class="text">	
	<h2><a  href="/learningenglish/english/features/lingohack_2022/ep-180522">How tourism and science work together in Antarctica</a></h2>
	<div class="details">
		<h3>
																<b>Episode 180522 </b>
							 
				 / 				  18 May 2022						</h3>
		<p>Learn language related to behaviour: alluring, remote, expedition, ambassadors, fragile</p>
	</div>
</div>
</li>
	</ul>
</div></div> <div class="clearfix"></div> </div> </div> <div class="bbcle-footer-nav-wrapper b-g-p"> 	<div id="bbcle-footer-nav" data-widget-index="footer-nav" class="bbcle-footer-nav bbcle-highlightme translated-nav">
					<div class="bbcle-footer-nav-list">
				<h2><span  data-i18n-message-id="About" class="not-translated _bbcle_translate_wrapper" lang="en">About</span></h2>
				<ul>
											<li><a href="/learningenglish/english/hygiene">About BBC Learning English</a></li>
											<li><a href="/learningenglish/english/hygiene/course-information">Courses</a></li>
											<li><a href="/learningenglish/english/hygiene/lowerintermediate-syllabus">Course site maps</a></li>
											<li><a href="/learningenglish/english/hygiene/frequently-asked-questions">Learning FAQ</a></li>
											<li><a href="/learningenglish/english/hygiene/contact">Contact BBC Learning English</a></li>
									</ul>
			</div>
					<div class="bbcle-footer-nav-list">
				<h2><span  data-i18n-message-id="Social" class="not-translated _bbcle_translate_wrapper" lang="en">Social</span></h2>
				<ul>
											<li><a href="https://www.tiktok.com/@bbclearningenglish">TikTok</a></li>
											<li><a href="https://www.youtube.com/user/bbclearningenglish">YouTube</a></li>
											<li><a href="https://www.instagram.com/bbclearningenglish">Instagram</a></li>
											<li><a href="https://twitter.com/bbcle">Twitter</a></li>
											<li><a href="https://www.facebook.com/bbclearningenglish.multimedia">Facebook</a></li>
											<li><a href="/learningenglish/english/hygiene/social-media">Social media house rules</a></li>
									</ul>
			</div>
				<a id="bbcle-footer-top-link" class="bbcle-footer-top-link" href="#"><span  data-i18n-message-id="Back to top" class="not-translated _bbcle_translate_wrapper" lang="en">Back to top</span></a>
		<a id="bbcle-footer-rss-link" class="bbcle-footer-rss-link" href="http://feeds.bbci.co.uk/learningenglish/english/features/lingohack_2022/rss"><span  data-i18n-message-id="RSS" class="not-translated _bbcle_translate_wrapper" lang="en">RSS</span></a>
	</div>
 </div> <div style="clear: both;"></div> <script type="text/javascript"> var translationStrings = []; var page_relative_path = "\/features\/lingohack_2022"; var site_stem = "\/learningenglish"; var site_name = "bbcle"; var content_language = "en"; var url_base = "https:\/\/www.bbc.co.uk\/learningenglish\/english"; var is_touch = false; if(	navigator.userAgent.match(/Android/i) || navigator.userAgent.match(/webOS/i) || navigator.userAgent.match(/iPhone/i) || navigator.userAgent.match(/iPad/i) || navigator.userAgent.match(/iPod/i) || navigator.userAgent.match(/BlackBerry/i) || navigator.userAgent.match(/Windows Phone/i)){ is_touch = true; } </script> <script type="text/javascript">  var BBCLECourseStructure = {"course":{"eiam":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-41":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-42":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-43":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-44":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-45":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-46":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-47":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-48":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-49":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-50":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-51":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-52":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-53":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-54":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-55":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-56":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-57":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-58":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-59":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-60":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-61":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-62":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-63":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-64":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-65":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-66":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-67":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-68":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-69":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-70":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-71":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-72":{"activity-1":[]},"session-73":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-74":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-75":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-76":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-77":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-78":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-79":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-80":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-81":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-82":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-83":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-84":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-85":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-86":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-87":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-88":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-2":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-41":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-42":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-43":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-44":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-45":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-46":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-47":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-48":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-49":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-50":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-51":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-52":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-53":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-54":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-55":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-56":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-57":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-58":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-59":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-60":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-61":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-62":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-63":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-64":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-65":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-66":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-67":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-68":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-69":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-70":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-71":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-3":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":[]},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"emw":{"unit-1":{"session-1":{"activity-1":[],"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":{"_completed":false,"score":-1,"maxScore":0},"activity-4":[]},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":{"_completed":false,"score":-1,"maxScore":0},"activity-3":[]}},"unit-2":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]}},"unit-3":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]}},"unit-4":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]}}},"english-expressions-afaan-oromoo":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-amharic":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-gujarati":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-korean":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-marathi":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":[],"activity-1 ":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-punjabi":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-telugu":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-expressions-tigrinya":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-in-action-korean":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-2":{"session-41":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-42":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-43":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-44":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-45":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-46":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-47":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-48":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-49":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-50":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-in-the-news-3-thai":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-in-the-news-gujarati":{"unit-1":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]},"session-13":{"activity-1":[]},"session-14":{"activity-1":[]},"session-15":{"activity-1":[]},"session-16":{"activity-1":[]},"session-17":{"activity-1":[]},"session-18":{"activity-1":[]}}},"english-in-the-news-marathi":{"unit-1":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]},"session-13":{"activity-1":[]},"session-14":{"activity-1":[]},"session-15":{"activity-1":[]},"session-16":{"activity-1":[]},"session-17":{"activity-1":[]},"session-18":{"activity-1":[]},"session-19":{"activity-1":[]}}},"english-in-the-news-punjabi":{"unit-1":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]},"session-13":{"activity-1":[]},"session-14":{"activity-1":[]},"session-15":{"activity-1":[]},"session-16":{"activity-1":[]},"session-17":{"activity-1":[]},"session-18":{"activity-1":[]}}},"english-in-the-news-telugu":{"unit-1":{"session-1":{"activity-1":[]},"session-2":{"activity-1":[]},"session-3":{"activity-1":[]},"session-4":{"activity-1":[]},"session-5":{"activity-1":[]},"session-6":{"activity-1":[]},"session-7":{"activity-1":[]},"session-8":{"activity-1":[]},"session-9":{"activity-1":[]},"session-10":{"activity-1":[]},"session-11":{"activity-1":[]},"session-12":{"activity-1":[]},"session-13":{"activity-1":[]},"session-14":{"activity-1":[]},"session-15":{"activity-1":[]},"session-16":{"activity-1":[]},"session-17":{"activity-1":[]}}},"english-in-the-news-thai":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-in-the-news-thai-2":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-matters-korean":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-on-the-street-thai":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-on-the-street-thai-2":{"unit-1":{"session-1":{"activity-1":[]},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":[]},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":[]}}},"english-together-afaan-oromoo":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-amharic":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-gujarati":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-korean":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-2":{"session-41":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-42":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-43":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-44":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-45":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-46":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-47":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-48":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-49":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-50":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-51":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-52":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-53":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-54":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-55":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-marathi":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":[]},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-punjabi":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-together-telugu":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":[]}},"english-together-tigrinya":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-6":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-7":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-8":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-9":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-10":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-11":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-12":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-13":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-14":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-15":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-16":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-17":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-18":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-19":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-20":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-21":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-22":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-23":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-24":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-25":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-26":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-27":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-28":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-29":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-30":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-31":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-32":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-33":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-34":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-35":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-36":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-37":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-38":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-39":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-40":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}}},"english-you-need":{"unit-1":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-2":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-3":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-4":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-5":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-6":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-7":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-8":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-9":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":[],"activity-3":[]},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-10":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-11":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-12":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-13":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-14":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-15":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-16":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-17":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0},"activity-2":[]},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit-18":{"session-1":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-2":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-3":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-4":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}},"session-5":{"activity-1":{"_completed":false,"score":-1,"maxScore":0}}},"unit
var comscore_settings = {"c2":"19999701","ns_site":"bbc","ns_c":"","b_vs_un":"ws","b_vs_ls":"learningenglish","b_imp_src":"ws","b_imp_ver":"1.0.0.0","b_app_type":"web","b_app_name":"","ns_type":"view","name":"learningenglish.english.features.lingohack2022","echoProfile":"world_service","b_page_type":"FIX|na","b_ad_enabled":"0","b_article_title":"BBC%20Learning%20English%20-%20Lingohack%20","b_article_id":"features;lingohack_2022","b_article_date":"","b_article_update":"","b_code_ver":"bbc_v1-0","b_site_section":"features","c1":"2"};
require(['jquery-1','module/stats/comscoreContextID', 'deviceInspector'], function ($,comscoreContextID, deviceInspector) {
    $(document).ready(function() {

        if(window.cutsTheMustard) {
            function udm_(e){var n=function(e){var n,s,t=window.bbccookies.get().split(";");for(s in t)if(t.hasOwnProperty(s)&&(n=t[s].replace(/^\s+/g,""),0===n.indexOf(e)))return n.substring((e+"=").length,n.length);return null};s_vi=comscoreContextID.getLegacyVisitorAlias();ns_alias=n("s1"),null==ns_alias&&(ns_alias=n("ckpf_sscid"));var s,t,i,a,r,c="comScore=",l=document,o=l.cookie,u="",f="indexOf",p="substring",d="length",g=2048,_="&ns_",h="&",w=window,m=w.encodeURIComponent||escape;if(o[f](c)+1)for(a=0,i=o.split(";"),r=i[d];r>a;a++)t=i[a][f](c),t+1&&(u=h+unescape(i[a][p](t+c[d])));e+=_+"_t="+ +new Date+_+"c="+(l.characterSet||l.defaultCharset||"")+"&b_vph="+$(window).height()+"&b_sr="+window.screen.width + 'x' + window.screen.height+"&b_vp="+$(window).width()+"&b_s_vi="+s_vi+"&b_synd_partner=BBC|RD|"+deviceInspector.getGroup()+"&ns_alias="+ns_alias+"&c8="+m(l.title)+u+"&c7="+m(l.URL)+"&c9="+m(l.referrer),e[d]>g&&e[f](h)>0&&(s=e[p](0,g-8).lastIndexOf(h),e=(e[p](0,s)+_+"cut="+m(e[p](s+1)))[p](0,g)),l.images?(t=new Image,w.ns_p||(ns_p=t),t.src=e):l.write("<","p","><",'img src="',e,'" height="1" width="1" alt="*"',"><","/p",">")}

            udm_('http'+(document.location.href.charAt(4)=='s'?'s://sb':'://b')+'.scorecardresearch.com/b?c2=19999701&ns_site=bbc&ns_c=&b_vs_un=ws&b_vs_ls=learningenglish&b_imp_src=ws&b_imp_ver=1.0.0.0&b_app_type=web&b_app_name=&ns_type=view&name=learningenglish.english.features.lingohack2022&b_page_type=FIX%7Cna&b_ad_enabled=0&b_article_title=BBC+Learning+English+-+Lingohack+&b_article_id=features%3Blingohack_2022&b_article_date=&b_article_update=&b_code_ver=bbc_v1-0&b_site_section=features&c1=2');
        } else {
            document.write('<img src="http'+(document.location.href.charAt(4)=='s'?'s://sb':'://b')+'.scorecardresearch.com/b?c2=19999701&ns_site=bbc&ns_c=&b_vs_un=ws&b_vs_ls=learningenglish&b_imp_src=ws&b_imp_ver=1.0.0.0&b_app_type=web&b_app_name=&ns_type=view&name=learningenglish.english.features.lingohack2022&echoProfile=world_service&b_page_type=FIX%7Cna&b_ad_enabled=0&b_article_title=BBC+Learning+English+-+Lingohack+&b_article_id=features%3Blingohack_2022&b_article_date=&b_article_update=&b_code_ver=bbc_nonjs&b_site_section=features&c1=2&c8=BBC+Learning+English+-+Lingohack+" height="1" width="1" alt="*">');
        }
    });
});

} catch (e) {

}
</script>

<noscript><img src="//sb.scorecardresearch.com/b?c2=19999701&ns_site=bbc&ns_c=&b_vs_un=ws&b_vs_ls=learningenglish&b_imp_src=ws&b_imp_ver=1.0.0.0&b_app_type=web&b_app_name=&ns_type=view&name=learningenglish.english.features.lingohack2022&echoProfile=world_service&b_page_type=FIX%7Cna&b_ad_enabled=0&b_article_title=BBC+Learning+English+-+Lingohack+&b_article_id=features%3Blingohack_2022&b_article_date=&b_article_update=&b_code_ver=bbc_nonjs&b_site_section=features&c1=2&c8=BBC+Learning+English+-+Lingohack+" height="1" width="1" alt="*"></noscript>
<!-- End comScore Inline Tag -->
	 <noscript> <link rel="stylesheet" type="text/css" href="https://static.live.bbc.co.uk/bbcle/0.2.66/style/noScript.css"> <div class="noscriptbanner"> <p>For a better experience please enable Javascript in your browser</p> </div> </noscript> <!-- End BBCWSDP content --> </div>
<div id="orb-footer" class="orb-footer" dir="ltr"> <div id="navp-orb-footer-promo"></div><aside role="complementary"><div id="orb-aside" class="orb-nav-sec b-r b-g-p"><div class="orb-footer-inner" role="navigation" aria-label="BBC"><h2 class="orb-footer-lead">Explore the BBC</h2><div class="orb-footer-primary-links"><ul class="domestic"><li class="orb-nav-home"><a href="https://www.bbc.co.uk"><span>Home</span></a></li><li class="orb-nav-news"><a href="https://www.bbc.co.uk/news"><svg class="product-icon" width="1.75em" height="1.75em" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewbox="0 0 512 512" enable-background="new 0 0 512 512" xml:space="preserve" focusable="false" aria-hidden="true"><g><path fill="#B80000" d="M302,424h-68c-0.552,0-1.052-0.224-1.414-0.586S232,422.552,232,422V306c0-0.552,0.224-1.052,0.586-1.414
                                        S233.448,304,234,304h68c0.552,0,1.052,0.224,1.414,0.586S304,305.448,304,306v116c0,0.552-0.224,1.052-0.586,1.414
                                        S302.552,424,302,424z"></path><path fill="#EB0000" d="M422,280H234c-0.552,0-1.052-0.224-1.414-0.586S232,278.552,232,278V90c0-0.552,0.224-1.052,0.586-1.414
                                        S233.448,88,234,88h188c0.552,0,1.052,0.224,1.414,0.586S424,89.448,424,90v188c0,0.552-0.224,1.052-0.586,1.414
                                        S422.552,280,422,280z"></path><path fill="#D30000" d="M206,328H90c-0.552,0-1.052-0.224-1.414-0.586S88,326.552,88,326V210c0-0.552,0.224-1.052,0.586-1.414
                                        S89.448,208,90,208h116c0.552,0,1.052,0.224,1.414,0.586S208,209.448,208,210v116c0,0.552-0.224,1.052-0.586,1.414
                                        S206.552,328,206,328z"></path></g></svg><span>News</span></a></li><li class="orb-nav-sport"><a href="https://www.bbc.co.uk/sport"><svg class="product-icon" width="1.75em" height="1.75em" version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewbox="0 0 512 512" enable-background="new 0 0 512 512" xml:space="preserve" focusable="false" aria-hidden="true"><g><path fill="
://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/js/orbit.js" async=""></script>   <script type="text/javascript">/*<![CDATA[*/
    (function() {
  function loadJs(url) {
      var script = document.createElement('script');
      script.type = 'text/javascript';
      script.src = url;
      script.async = true;
      document.getElementsByTagName('body')[0].appendChild(script);
  }
     window.bbcuser.isUKCombined().then(function(isUK) {
       if (isUK) {
         loadJs('https://static.files.bbci.co.uk/orbit/644077edc7f09faed9dd44fb4c1fae48/js/edr.js');
       }
     });
   })();
   /*]]>*/</script>      <script type="module">if (window.bbcuser && window.bbcuser.isUKCombined) {
        bbcuser.isUKCombined().then(function (isUK) {
            if (isUK) {
                import('https://nav.files.bbci.co.uk/searchbox/c8bfe8595e453f2b9483fda4074e9d15//js/search-suggest.js').then(drawer => {
                    drawer.setupSearchDrawer({
                        searchboxAppStaticPrefix: 'https://nav.files.bbci.co.uk/searchbox/c8bfe8595e453f2b9483fda4074e9d15/',
                        variant: 'default',
                        searchScope: 'bbcle',
                    });
                });
            }
        });
    }</script>     <script type="text/javascript" src="https://nav.files.bbci.co.uk/navpromo/4d6b8fa133eb1d43fbcc4a7b2162a86f/js/footerpromo.js" data-base="https://navpromo.api.bbci.co.uk" data-variant="default" async=""></script>    <script type="text/javascript">window.COOKIES_STATIC_HOST="https://static.files.bbci.co.uk/cookies/d3bb303e79f041fec95388e04f84e716/cookie-banner/cookie-prompt/"</script><script src="https://static.files.bbci.co.uk/cookies/d3bb303e79f041fec95388e04f84e716/cookie-banner/cookie-banners.bundle.js" async=""></script>  <script src="https://nav.files.bbci.co.uk//user-activity-helper/1209f4ab453870b12c05d61f50198f1e/js/detectview.bundle.js" async=""></script><script type="text/javascript">"use strict";window.__reverb.__reverbLoadedPromise.then(function(e){return e.initialise().then(function(){return e.viewEvent()})},function(){console.log("Failed to load reverb. No event sent")});</script> <script src="https://mybbc.files.bbci.co.uk/notification-ui/5.0.19//js/NotificationsMain.js" defer="defer"></script><script type="module">const drawerAPI = await window.shimport('orbit-drawer');
                           # !window.location.href.includes('/notifications') && 
                           window.bbcuser.isUKCombined().then(function(isUK) {
                            if (isUK) {
                             window.NotificationsMain.run(drawerAPI, "https://mybbc.files.bbci.co.uk/notification-ui/5.0.19/");}})</script> <script src="https://static.live.bbc.co.uk/bbcle/0.2.66/script/cssp.js"></script> <script type="text/javascript"> bbcRequireMap = { "jquery-1.4":"//static.stage.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.4", "jquery-1.9":"//static.stage.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.9.1", "jquery-1.12":"//static.stage.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.12.0.min", "jquery-2.2":"//static.stage.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-2.2.0.min", "istats-1":"//nav.files.bbci.co.uk/nav-analytics/0.1.0-43/js/istats-1", "swfobject-2":"//static.stage.bbci.co.uk/frameworks/swfobject/0.1.10/sharedmodules/swfobject-2", "gelui-1":"//static.stage.bbci.co.uk/frameworks/gelui/0.9.13/sharedmodules/gelui-1", "cssp!gelui-1/overlay":"//static.stage.bbci.co.uk/frameworks/gelui/0.9.13/sharedmodules/gelui-1/overlay.css", "relay-1":"//static.stage.bbci.co.uk/frameworks/relay/0.2.6/sharedmodules/relay-1", "clock-1":"//static.stage.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/clock-1", "canvas-clock-1":"//static.stage.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/canvas-clock-1", "clock-1":"//static.stage.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/clock-1.css", "jssignals-1":"//static.stage.bbci.co.uk/frameworks/jssignals/0.3.6/modules/jssignals-1", "jcarousel-1":"//static.stage.bbci.co.uk/frameworks/jcarousel/0.1.10/modules/jcarousel-1", "bump-3":"//emp.bbci.co.uk/emp/bump-3/bump-3" }; require({ paths: bbcRequireMap, waitSeconds: 30 }); </script> <script src="https://static.live.bbc.co.uk/bbcle/0.2.66/script/bbcle.js"></script> </body> </html> '''

# %%
soup2 = '''

'''

# %%
//div[@class='related-words']

# %%
def get_struc_data(topic, user_agent):
    URL = "https://www.bbc.co.uk/learningenglish/english/course/{}".format(topic)
    HEADERS = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'user-agent': user_agent,
    'access-control-allow-credentials': 'true'
    }
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    dom = etree.HTML(str(soup))
    # target_page = ['https://www.bbc.co.uk'+str(s) for s in dom.xpath("//*[@id='navIndex-4']//a/@href")]
    # platform/title/date/url
    url_list = [str(s) for s in dom.xpath("//div[@class='details']/h3/a/@href")]
    date_list = [str(s) for s in dom.xpath("//span[@class='date']/text()")]
    title_list = ["https://www.bbc.co.uk"+str(s) for s in dom.xpath("//div[@class='details']/h3/a/text()")]
    df = pd.DataFrame(
    {
        'title': title_list,
        'date': date_list,
        'url': url_list
    })
    return df
###
def get_unstruc_data(topic, user_agent):
    URL = "https://www.bbc.co.uk/learningenglish/english/course/{}".format(topic)
    HEADERS = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'user-agent': user_agent,
        'access-control-allow-credentials': 'true'
        }
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    dom = etree.HTML(str(soup))
    # target_page = ['https://www.bbc.co.uk'+str(s) for s in dom.xpath("//*[@id='navIndex-4']//a/@href")]
    # platform/title/date/url
    url_list = ["https://www.bbc.co.uk"+str(s) for s in dom.xpath("//div[@class='details']/h3/a/@href")]
    date_list = [str(s) for s in dom.xpath("//span[@class='date']/text()")]
    title_list = [str(s) for s in dom.xpath("//div[@class='details']/h3/a/text()")]
    df = pd.DataFrame(
    {
        'title': title_list,
        'date': date_list,
        'url': url_list
    })
    return df

# %%
struc_list = ['newsreview-2022', 'newsreview', 'fakenews']
unstruc_list = ['lingohack_2022', 'englishinthenews']
df = pd.DataFrame(columns=['title', 'date', 'url'])

for i in struc_list:
    df = df.append(get_struc_data(i, get_random_agent()), ignore_index=True)
    sleep(randint(3,15))

# for i in unstruc_list:
#     df = df.append(get_unstruc_data(i), ignore_index=True)
#     sleep(randint(3,15))
df['platform'] = 'BBC'

df.to_csv('BBC.csv', encoding='utf-8-sig', columns=['platform', 'date', 'title', 'url'])
tmp = pd.read_csv('BBC.csv', index_col=0)
tmp
# Out:
# /var/folders/6f/v4g3dkkj0b54w0sc2l43bkqm0000gn/T/ipykernel_19249/3354571601.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(get_struc_data(i, get_random_agent()), ignore_index=True)
#    platform         date                                              title  \
# 0       BBC  10 Jan 2022  https://www.bbc.co.ukDjokovic vs Australia: No...
# 1       BBC  18 Jan 2022  https://www.bbc.co.ukTonga: Volcano and tsunam...
# 2       BBC  25 Jan 2022  https://www.bbc.co.ukUkraine: US tells embassy...
# 3       BBC  01 Feb 2022  https://www.bbc.co.ukNadal: Star breaks record...
# 4       BBC  07 Feb 2022  https://www.bbc.co.ukThe Queen: 70 years on th...
# ..      ...          ...                                                ...
# 62      BBC  02 Jun 2020     https://www.bbc.co.ukFake news and coronavirus
# 63      BBC  11 Sep 2020  https://www.bbc.co.ukAgendas, actors and algor...
# ...

# %% [markdown]
# ---
# ---

# %%
from requests import Request, Session

s = Session()
req = Request('GET',  'https://www.bbc.co.uk/learningenglish/english/course/lingohack_2022', data=data, headers=headers)

prepped = s.prepare_request(req)

# do something with prepped.body
prepped.body = 'Seriously, send exactly these bytes.'

# do something with prepped.headers
prepped.headers['Keep-Dead'] = 'parrot'

resp = s.send(prepped,
    stream=stream,
    verify=verify,
    proxies=proxies,
    cert=cert,
    timeout=timeout
)

print(resp.status_code)
# Out:
# {'user-agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'text/html', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'upgrade-insecure-requests': '1', 'accept-ranges': 'bytes'}

# %%
webpage.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '29276', 'Content-Type': 'text/html; charset=UTF-8', 'X-Powered-By': 'PHP/7.3.33', 'Cache-Control': 'public, max-age=600,stale-if-error=1200,stale-while-revalidate=10', 'X-BBC-Edge-Scheme': 'https', 'nel': '{"report_to":"default","max_age":2592000,"include_subdomains":true,"failure_fraction":0.05}', 'via': '1.1 BBC-GTM, 1.1 varnish', 'req-svc-chain': 'FASTLY,GTM', 'X-BBC-Edge-Cache-Status': 'MISS', 'X-BBC-Origin-Response-Status': '404', 'report-to': '{"group":"default","max_age":2592000,"endpoints":[{"url":"https://default.bbc-reporting-api.app/report-endpoint","priority":1}],"include_subdomains":true}', 'Server': 'BBC-GTM', 'Strict-Transport-Security': 'max-age=31536000', 'Permissions-Policy': 'browsing-topics=(), join-ad-interest-group=(), run-ad-auction=()', 'Fastly-Restarts': '1', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Thu, 15 Dec 2022 01:28:20 GMT', 'X-Fastly-Cache-Status': 'HIT-CLUSTER', 'X-Served-By': 'cach
# ...

# %%
s = requests.Session()

s.get('https://www.bbc.co.uk/learningenglish/english/course/lingohack_2022')
r = s.get('https://httpbin.org/cookies')

print(r.text)
# '{"cookies": {"sessioncookie": "123456789"}}'
# Out:
# {
#   "cookies": {}
# }

# %%
from urllib.request import urlopen
HEADERS = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'user-agent': 'wswp',
    'access-control-allow-credentials': 'true'
    }
webpage = requests.get(url='https://www.bbc.co.uk/learningenglish/english/course/lingohack_2022')
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
webpage
# Out:
# <Response [404]>
