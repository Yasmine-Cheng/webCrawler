# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.stockq.org/funds/allianz_tw.php"
  
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
            (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',\
            'Accept-Language': 'en-US, en;q=0.5'})
  
webpage = requests.get(URL, headers=HEADERS)
soup = BeautifulSoup(webpage.content, "html.parser")
soup
# Out:
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="提供每日最新安聯投信境內基金淨值、基金配息資訊、與參考指數報酬率比較。" name="description">
# <title>安聯投信境內基金淨值 - StockQ.org </title>
# <link href="https://www.stockq.org/funds/allianz_tw.php" rel="canonical"/>
# <link href="https://m.stockq.org/funds/allianz_tw.php" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="240" http-equiv="refresh"/>
# <link href="/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="/css/fund2.css" rel="stylesheet" type="text/css"/>
# <script src="/js/stockq.js" type="text/javascript"></script>
# <script src="/js/sorttable.js" type="text/javascript"></script>
# <link href="/favicon.ico" rel="icon" type="image/x-icon">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-9803646600609510",
# ...

# %%
table = soup.find('table', {'class': 'fundpricetable'})
table
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="fundpricetable">
# <tr align="middle">
# <td bgcolor="#ffffff" width="10"><img border="0" height="18" src="img/s.gif" width="10"/></td>
# <td align="left" bgcolor="#ffffff" class="head5tw" valign="bottom" width="280"><font color="#000066"><b>基金名稱</b></font></td>
# <td bgcolor="#ffffff" width="1"><img border="0" height="1" src="img/s.gif" width="1"/></td>
# <td align="center" bgcolor="#ffffff" class="head5tw" valign="bottom" width="55"><font color="#000066"><b>幣別</b></font></td>
# <td bgcolor="#ffffff" width="1"><img border="0" height="1" src="img/s.gif" width="1"/></td>
# <td align="center" bgcolor="#ffffff" class="head5tw" valign="bottom" width="50"><font color="#000066"><b>淨值</b></font></td>
# <td bgcolor="#ffffff" width="1"><img border="0" height="1" src="img/s.gif" width="1"/></td>
# <td align="center" bgcolor="#ffffff" class="head5tw" valign="bottom" width="60"><font color="#000066"><b>漲跌</b></font></td>
# ...

# %%
columns = [th.text.replace('\n', '') for th in table.find('tr').find_all('td')]
trs = table.find_all('tr')[1:]
rows = list()
for tr in trs:
    rows.append([td.text for td in tr.find_all('td')])
# ###
df = pd.DataFrame(data=rows, columns=columns)

# %%
df = df.drop('', axis=1)
df = df[df['基金名稱'].notnull()]

# %%
df.to_csv('allianz.csv', encoding='utf-8-sig')
tmp = pd.read_csv('allianz.csv', index_col=0)
tmp
# Out:
#                             基金名稱   幣別       淨值      漲跌      比例     日期
# 2                       安聯中國東協基金   台幣  12.5500 -0.0600  -0.48%  11/25
# 4                       安聯中國策略基金   台幣  20.1900 -0.1100  -0.54%  11/25
# 6                       安聯中國策略基金   美元  15.5600 -0.0200  -0.13%  11/25
# 8                       安聯中國策略基金  人民幣   6.7100  0.0000    0.00  11/25
# 10                     安聯中華新思路基金   台幣  17.5200 -0.1000  -0.57%  11/25
# ..                           ...  ...      ...     ...     ...    ...
# 184   安聯新興債券收益組合基金-HB類型/月配息/台幣避險   台幣   7.2615  0.0447   0.62%  11/25
# 186  安聯新興債券收益組合基金-HN類型/月配息/人民幣避險  人民幣   7.4319  0.0527   0.71%  11/25
# 188   安聯新興債券收益組合基金-HN類型/月配息/台幣避險   台幣   7.2617  0.0448   0.62%  11/25
# 190         安聯新興債券收益組合基金-N類型/月配息   美元   7.3379  0.0349   0.48%  11/25
# 192         安聯新興債券收益組合基金-N類型/月配息   台幣   7.5919 -0.0336  -0.44%  11/25
#
# [94 rows x 6 columns]
